# %%
from openff.toolkit import Molecule
from utils import utils
import os

# Define the path to your SDF file
inp_file = "/home/erikna/compchem/md_data/Terpene_cyclases/test.sdf"
pH = 7.4

#optional charge correction
utils.prepare_ligand_md(inp_file, pH)

#split filename
ext = os.path.splitext(inp_file)[-1].lstrip(".")
name = os.path.splitext(inp_file)[0].lstrip(".")

# Read the SDF file with OpenFF-toolkit and visuallize
ligand = Molecule.from_file(f"{name}.sdf")
ligand.visualize()
# Out:
# Adjusting charges for /home/erikna/compchem/md_data/Terpene_cyclases/test
# Total charge infeered as -3
# /home/erikna/miniforge3/envs/whatcat/lib/python3.12/site-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(
