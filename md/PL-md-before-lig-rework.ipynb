# %%
from openmm.app import *
from openmm import *
from openmm.unit import *
import sys
from openff.toolkit import Molecule
from openmmforcefields.generators import SystemGenerator
from pdbfixer import PDBFixer
import argparse
import matplotlib.pyplot as plt
from utils import utils, analysis, plot

#only needed for devwork
import importlib
importlib.reload(utils)

#fake command line arguments
sys.argv = ["fake_name", "ranjani/arg/Lys122Ala-Val123Arg.pdb", "--pdbfix","True","-l", "ranjani/arg/ligOH.sdf", "-t", "10", "-dt", "4", "--resname", "UNK", "--dist", """resid 131 atom OG1, resname UNK atom N1x"""]

#Start the command line parser
parser = argparse.ArgumentParser(
                    prog='POS MD script',
                    description=(
                    "This script sets up a OPENMM  simulation of a protein (amber ff14)," 
                    "any small molecules/cofactors (Sage 2.2.1) as well as  water/ions using a 12-6 model (tip3pfb)."
                    "If using --pdbfix True then the structure will be prepared automatically. Otherwise prep is fully manual"),
                    epilog='Use with care and acknowledge Erik Sundén and the Per-Olof Syrén group at KTH Sweden')

parser.add_argument("pdb", type = str, help = "dockpreped PDB structure of the structure you want to simulate, including ligands") 
parser.add_argument("--pdbfix", type = str, default = "True", help = ("True or False depending on if your structure shall be PDBfixed." 
                                                                     "default = True \n good if you have a SEQRES and unresolved loops."
                                                                     "BEWARE, this function also removes all protein hydrogens and readds them" ))
parser.add_argument("-l", "--lig", type = str, action="append", default = None, help = ("optional parameter, SDF file containing all nonstandard ligands and cofactors." 
                                                                       "Convenientlly produced by drawing in chemdraw and exporting as SDF then docking with added hydrogens."
                                                                       "This is easilly done by checking ChimeraX dockpreps charge assignment when running dockprep.")) 
parser.add_argument("-t", "--timeprod", type = float, default= 0.2, help="Production simulation time in ns. Accepts floats and ints")
parser.add_argument("-dt", "--timestep", type = int, default= 4, help="Simulation timestep in fs. Accepts ints")
parser.add_argument("--resname", type = str, action="append", default= None, help="Residue names in PDB for which you want further analysis, eg ligand.\n"
                                                                            "several --resnames can be used at once", required=False)
parser.add_argument("--debug", type = bool, default= False, help="debug mode, prints more information while running", required=False)
parser.add_argument("--dist", type = str, action="append", default= None, help="""a pair of atom numbers eg "resid 131 atom OG1", "resname UNK atom N1x" for which you want 
a distance plot eg for monitoring near-attack conformations. specify using MDAnalysis/VMD natural language queries""", required=False)

# Parse arguments
args = parser.parse_args()

# Extract into variables
pdb_file = args.pdb
pdb_fixer = args.pdbfix
ligand_file = args.lig
simulation_time_ns = args.timeprod
timestep = args.timestep
pdb_name = os.path.splitext(pdb_file)[0]
analysis_resnames = args.resname
debug = args.debug
dist_residues = args.dist

#calculate simulation length
production_steps = int(simulation_time_ns / (timestep * 10**-6))
equillibration_time = 40 #picoseconds
equillibration_steps = int(equillibration_time / (timestep * 10**-3))
reporting_time = 1 #ps
reporting_frequency = int(reporting_time / (timestep * 10**-3))

#this specifies the size, start and end of the 2D RMSD matrix
#BEWARE N^2 scaling operation
sparsity = int((simulation_time_ns * 1000 / reporting_time) / 500) #500 is the biggest amount of frames judged to be plausible to compute
if sparsity == 0:
    sparsity = 1
start_frame = 0
end_frame = -1 #last frame

if pdb_fixer == "True" or pdb_fixer == "true":
    #remove hydrogens
    utils.remove_hydrogens(f"{pdb_name}.pdb", f"{pdb_name}_fixed.pdb")

    #Run PDBfixer
    fixer = PDBFixer(filename=f"{pdb_name}_fixed.pdb")
    #we remove and then re-add hydrogens to prevent shenanigans related to disulfide bonds
    fixer.addMissingHydrogens(7.4)  # add missing hydrogens
    fixer.findMissingResidues()

    #to avoid changing list we iterate over we copy everything to separate objects
    chains = list(fixer.topology.chains())
    keys = list(fixer.missingResidues.keys())  

    #Then we remove terminal residues we don´t know anything about
    for key in keys:
        chain = chains[key[0]]
        if key[1] == 0 or key[1] == len(list(chain.residues())):
            del fixer.missingResidues[key]

    fixer.findNonstandardResidues()
    fixer.replaceNonstandardResidues()
    #fixer.removeHeterogens(False)
    fixer.findMissingAtoms()
    fixer.addMissingAtoms()
    PDBFile.writeFile(fixer.topology, fixer.positions, open(f"{pdb_name}_fixed.pdb", 'w'))

    
    pdb = PDBFile(f"{pdb_name}_fixed.pdb")

elif pdb_fixer == "False" or pdb_fixer == "false":
    #if not fixing PDB
    pdb = PDBFile(f"{pdb_name}.pdb")

#if simulating with ligand
if ligand_file != None:
    
    #read ligand file
    ligand_mol = Molecule.from_file(ligand_file)

    #make sure ligand_mol is a list, requiered by systemgenerator
    if type(ligand_mol) != list:
        ligand_mol = [ligand_mol]

    # Specify the forcefield
    # Initialize a SystemGenerator using the Sage.2.1 for the ligand and tip3p for the water.
    #TODO figure out if we want HMR, constrain HBOND, 4 fs, langevinmiddle or another solution like 3 fs no HMR or a variable time langevin integrator (this would however lose the BAOB correction)
    #TODO This is really important
    forcefield_kwargs = {'constraints': HBonds, 'rigidWater': True, 'removeCMMotion': True, 'hydrogenMass' : 1.5 * amu }
    system_generator = SystemGenerator(
        forcefields=['amber14-all.xml', 'amber14/tip3pfb.xml'],
        small_molecule_forcefield='openff-2.2.1.offxml',
        molecules=ligand_mol,
        forcefield_kwargs=forcefield_kwargs, cache="ligands.json")
    
    #start a modeller
    modeller = Modeller(pdb.topology, pdb.positions)
    #residues=modeller.addHydrogens(system_generator.forcefield, pH = 7)
    
    #adding ligand to protein pdb
    for ligand in ligand_mol:
        lig_top = ligand.to_topology()
        modeller.add(lig_top.to_openmm(), lig_top.get_positions().to_openmm())

#if not simulating with ligand
elif ligand_file == None:
    # Specify the forcefield
    # Initialize a SystemGenerator using the Sage.2.1 for the ligand and tip3p for the water.
    forcefield_kwargs = {'constraints': HBonds, 'rigidWater': True, 'removeCMMotion': True, 'hydrogenMass' : 1.5 * amu }
    system_generator = SystemGenerator(
        forcefields=['amber14-all.xml', 'amber14/tip3pfb.xml'],
        small_molecule_forcefield='openff-2.2.1.offxml',
        forcefield_kwargs=forcefield_kwargs, cache="ligands.json")
    
    #start a modeller
    modeller = Modeller(pdb.topology, pdb.positions)
    #residues=modeller.addHydrogens(system_generator.forcefield, pH = 7)

modeller.deleteWater()
modeller.addSolvent(system_generator.forcefield, padding=1.0*nanometer)

# Create the system using the SystemGenerator
system = system_generator.create_system(modeller.topology)

#set precision and platform
properties = {"Precision": "mixed"} #improves energy conservation resulting in larger stable timesteps. decreases speed ca 5%
platform = Platform.getPlatformByName("CUDA")

#set up simulation
integrator = LangevinMiddleIntegrator(300*kelvin, 1/picosecond, timestep * femtoseconds)
simulation = Simulation(modeller.topology, system, integrator, platform = platform)
simulation.context.setPositions(modeller.positions)

print("Minimizing energy")
simulation.minimizeEnergy()

print("Running NVT equillibration")
simulation.step(equillibration_steps)

system.addForce(openmm.MonteCarloBarostat(1 * bar, 300 * kelvin))
simulation.context.reinitialize(preserveState=True) #needed to add in the barostat

print("Running NPT equillibration")
simulation.step(equillibration_steps)

#save pdb
state = simulation.context.getState(getPositions=True)
with open(pdb_name + "_equillibrated.pdb", "w") as file:
    PDBFile.writeFile(simulation.topology, state.getPositions(), file)

#add reporters
#print to terminal
simulation.reporters.append(StateDataReporter(sys.stdout, 1000, step=True,
        potentialEnergy=True, temperature=True, volume=True, remainingTime=True, totalSteps=equillibration_steps *2 + production_steps, speed=True))

#saved to file
simulation.reporters.append(StateDataReporter(f"{pdb_name}_md_log.txt", reporting_frequency, step=True,
        potentialEnergy=True, temperature=True, volume=True))
simulation.reporters.append(DCDReporter(f"{pdb_name}_trajectory.dcd", reporting_frequency))

print("Running production NPT")
simulation.step(production_steps)

#save pdb
state = simulation.context.getState(getPositions=True)
with open(f"{pdb_name}_final.pdb", "w") as file:
    PDBFile.writeFile(simulation.topology, state.getPositions(), file)
# Out:
# /home/erikna/miniforge3/envs/md/lib/python3.12/site-packages/openff/toolkit/utils/rdkit_wrapper.py:1661: SyntaxWarning: invalid escape sequence '\*'
#   """
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 109
#     106 #if simulating with ligand
#     107 if ligand_file != None:
#     108     #read ligand file
# --> 109     ligand_mol = Molecule.from_file(ligand_file)
#     111     #make sure ligand_mol is a list, requiered by systemgenerator
#     112     if type(ligand_mol) != list:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/openff/toolkit/topology/molecule.py:3872, in FrozenMolecule.from_file(cls, file_path, file_format, toolkit_registry, allow_undefined_stereo)
#    3870     if isinstance(file_path, pathlib.Path):
#    3871         file_path = file_path.as_posix()
# -> 3872     mols = toolkit.from_file(
#    3873         file_path,
#    3874         file_format=file_format,
#    3875         allow_undefined_stereo=allow_undefined_stereo,
#    3876         _cls=cls,
#    3877     )
#    3878 elif hasattr(file_path, "read"):
#    3879     file_obj = file_path
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/openff/toolkit/utils/rdkit_wrapper.py:1090, in RDKitToolkitWrapper.from_file(self, file_path, file_format, allow_undefined_stereo, _cls)
#    1077     mols.extend(
#    1078         self._process_sdf_supplier(
#    1079             sdf_supplier,
#    (...)
#    1082         )
#    1083     )
#    1085 elif file_format == "SMI":
#    1086     # TODO: We have to do some special stuff when we import SMILES (currently
#    1087     # just adding H's, but could get fancier in the future). It might be
#    1088     # worthwhile to parse the SMILES file ourselves and pass each SMILES
#    1089     # through the from_smiles function instead
# -> 1090     for rdmol in Chem.SmilesMolSupplier(file_path, titleLine=False):
#    1091         if rdmol is None:
#    1092             # Skip any lines that could not be processed.
#    1093             # This is consistent with the SDF reader and with
#    1094             # the OpenEye toolkit wrapper.
#    1095             continue
#
# OSError: File error: Bad input file ranjani/arg/ligOH.smi

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import MDAnalysis as mda 
import pandas as pd
from multiprocessing import cpu_count
import dask
import time
import os

#only needed for devwork
import importlib
importlib.reload(utils)
importlib.reload(analysis)
importlib.reload(plot)

#TODO write a analysis class using the multithreaded functions
#TODO write a input file format reader

#get how much we can parallelize
n_jobs = cpu_count()
align = True

#settings for the 2D RMSD algorithm
#Now set automatically above if not explicitlly requested
if False:
    sparsity = 40 #every nth frame will be analyzed in the 2D RMSD computation
    start_frame = None
    end_frame = None

print("Centering and aligning protein in PBC" if align else "Centering protein in PBC")

start_time = time.time()

#center proteins, This also resets the time of the first snapshot to 0 ps thus removing equillibration time
centered_traj_name = f"{pdb_name}_trajectory.dcd"
mda_traj = utils.parallel_center_trajectory(f"{pdb_name}_final.pdb", f"{pdb_name}_trajectory.dcd", align=align, n_jobs=n_jobs, output_filename = centered_traj_name) 
print(f"{round(time.time() - start_time,2)}s used for centering")

#dt is in ps
time_offset = 0 #redundant due to centering
mda_traj = mda.Universe(f"{pdb_name}_final.pdb", centered_traj_name, dt=reporting_time, time_offset=time_offset)

#load state data reporter information from memory
column_names = ["Step", "Potential Energy (kJ/mole)", "Temperature (K)", "Box Volume (nm^3)"]
#header=None prevents using the first row as headers avoiding "#"steps" as a name
#nrows = None allows us to read the whole csv not just the first 100 rows
md_log_df = pd.read_csv(f"{pdb_name}_md_log.txt", names=column_names, comment="#", header=None, nrows=None)  
#TODO put df in a whatcat.analysis class

# Extract Trajectory Time
times = np.array([ts.time for ts in mda_traj.trajectory])  # Extract time (in ps)
md_log_df.insert(0, "Time (ps)", times)

print("computing RMSD")
start_time = time.time()
# overwrite selection and stuff from centering
ref = mda_traj.copy()   # Create a copy of the universe in the first frame
ref.trajectory[0] #set frame to 0 explicitlly
backbone = mda_traj.select_atoms("backbone")

#create a temporary sparse trajectory for 2D RMSD analysis to save resorces in the N^2 scaling operation
sparse_traj = f"{pdb_name}_trajectory_sparse.dcd"
utils.write_trajectory(mda_traj, f"{pdb_name}_trajectory_sparse.dcd", sparsity=sparsity, start_frame=start_frame, end_frame=end_frame)

rmsd_analysis = mda.analysis.rms.RMSD(backbone, ref, select="backbone", ref_frame=0, superposition = False).run(backend="multiprocessing", n_workers= n_jobs)
rmsd_backbone = rmsd_analysis.results.rmsd[:, 2]  # Extract RMSD values (column index 2)

#save the 1D RMSD data
rmsd_back_df = pd.DataFrame({"RMSD backbone": rmsd_backbone})
md_log_df = pd.concat([md_log_df, rmsd_back_df], axis=1) 

rmsd_backbone_matrix = analysis.parallel_2d_rmsd(f"{pdb_name}_final.pdb", sparse_traj, "backbone", n_jobs=n_jobs)
plot.heatmap(rmsd_backbone_matrix, "tims (ps)", "tims (ps)", "RMSD (Å)", f"2D RMSD for backbone", f"2d_rmsd_backbone", pdb_name, sparsity, start_frame)

if analysis_resnames != None:
    residue_rmsd = []
    rmsd_residue_names = []
    for resname in analysis_resnames:

        #compute 1D RMSD
        residue = mda_traj.select_atoms(f"resname {resname}")
        rmsd_residue_names.append(f"RMSD {resname}")
        rmsd_analysis = mda.analysis.rms.RMSD(residue, ref, select=f"resname {resname}", ref_frame=0, superposition = False).run(backend="multiprocessing", n_workers= n_jobs)
        residue_rmsd.append(rmsd_analysis.results.rmsd[:, 2]) #we add a extra set of [] to "transpose" the list

        #compute 2D RMSD
        rmsd_2d_residue = analysis.parallel_2d_rmsd(f"{pdb_name}_final.pdb", sparse_traj, f"resname {resname}", n_jobs=n_jobs)
        plot.heatmap(rmsd_2d_residue, "tims (ps)", "tims (ps)", "RMSD (Å)", f"2D RMSD for {resname}", f"2d_rmsd_{resname}", pdb_name, sparsity, start_frame)

    #save the 1d data    
    rmsd_lig_df = pd.DataFrame(np.array(residue_rmsd).T, columns=rmsd_residue_names)
    md_log_df = pd.concat([md_log_df, rmsd_lig_df], axis=1) 

#remove temp sparse traj
os.remove(sparse_traj)

print(f"{round(time.time() - start_time,2)}s used for RMSD")

#compute RMSF
print("computing RMSF")
start_time = time.time()

rmsf_result = analysis.calc_rmsf_parallel(f"{pdb_name}_final.pdb", centered_traj_name, n_jobs=n_jobs)

protein = mda_traj.select_atoms('protein')
residue_list = range(1, len(protein.residues) +1)
plot.line_plotter_2d(residue_list, rmsf_result, "residue", "RMSF (Å)", pdb_name, "1d_rmsf")

print(f"{round(time.time() - start_time,2)}s used for RMSF")

# Compute Radius of Gyration
print("computing rgyr")
start_time = time.time()
protein = mda_traj.select_atoms('protein')
rga = mda.analysis.base.AnalysisFromFunction(analysis.radgyr, mda_traj.trajectory, protein, protein.masses, total_mass=np.sum(protein.masses)).run(backend="multiprocessing", n_workers= n_jobs)

rg_labels = ["Rg_all", "Rg_x", "Rg_y", "Rg_z"]
rg_df = pd.DataFrame(rga.results.timeseries, columns=rg_labels)
md_log_df = pd.concat([md_log_df, rg_df], axis=1)
print(f"{round(time.time() - start_time,2)}s used for rgyr")

#save df
md_log_df.to_csv(f"{pdb_name}_results.csv", index=False)  # Saves without the index column

if debug == True:
    print(md_log_df)
    print(md_log_df.shape)
    print("\n")

#check equillibration
analysis.equillibration_check(md_log_df, reporting_time, dt=100)

#plot
plot.line_plotter_2d(md_log_df["Time (ps)"], md_log_df["Potential Energy (kJ/mole)"], "Time (ps)", "Potential Energy (kJ/mole)", pdb_name, "energy")
plot.line_plotter_2d(md_log_df["Time (ps)"], md_log_df["Temperature (K)"], "Time (ps)", "Temperature (K)", pdb_name, "temperature")
plot.line_plotter_2d(md_log_df["Time (ps)"], md_log_df["Box Volume (nm^3)"], "Time (ps)", "Box Volume (nm^3)", pdb_name, "volume")
plot.line_plotter_2d(md_log_df["Time (ps)"], md_log_df[["RMSD backbone"] + rmsd_residue_names], "Time (ps)", "RMSD (Å)", pdb_name, "_rmsd")
plot.line_plotter_2d(md_log_df["Time (ps)"], md_log_df[["Rg_all", "Rg_x", "Rg_y", "Rg_z"]], "Time (ps)", "Radius of gyration (Å)", pdb_name, "rg")
# Out:
# Centering and aligning protein in PBC
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[5], line 37
#      36 centered_traj_name = f"{pdb_name}_trajectory.dcd"
# ---> 37 mda_traj = utils.parallel_center_trajectory(f"{pdb_name}_final.pdb", f"{pdb_name}_trajectory.dcd", align=align, n_jobs=n_jobs, output_filename = centered_traj_name)
#      38 print(f"{round(time.time() - start_time,2)}s used for centering")
#
# File ~/md/utils/utils.py:132, in parallel_center_trajectory(pdb_filename, traj_filename, align, n_jobs, output_filename)
#     131 # Load Universe once to get number of frames.
# --> 132 u = mda.Universe(pdb_filename, traj_filename)
#     133 n_frames = u.trajectory.n_frames
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:417, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, fudge_factor, lower_bound, in_memory, context, to_guess, force_guess, in_memory_step, *coordinates, **kwargs)
#     416     self.filename = _check_file_like(topology)
# --> 417     topology = _topology_from_file_like(self.filename,
#     418                                         topology_format=topology_format,
#     419                                         **kwargs)
#     421 if topology is not None:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:121, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     118 if (err.errno is not None and
#     119     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120     # Runs if the error is propagated due to no permission / file not found
# --> 121     raise sys.exc_info()[1] from err
#     122 else:
#     123     # Runs when the parser fails
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:113, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     112     with parser(topology_file) as p:
# --> 113         topology = p.parse(**kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/topology/PDBParser.py:215, in PDBParser.parse(self, **kwargs)
#     209 """Parse atom information from PDB file
#     210
#     211 Returns
#     212 -------
#     213 MDAnalysis Topology object
#     214 """
# --> 215 top = self._parseatoms()
#     217 try:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/topology/PDBParser.py:252, in PDBParser._parseatoms(self)
#     251 last_wrapped_serial = 100000  # if serials wrap, start from here
# --> 252 with util.openany(self.filename) as f:
#     253     for line in f:
#
# File ~/miniforge3/envs/md/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:326, in openany(datasource, mode, reset)
#     284 """Context manager for :func:`anyopen`.
#     285
#     286 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     324 :func:`anyopen`
#     325 """
# --> 326 stream = anyopen(datasource, mode=mode, reset=reset)
#     327 try:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:406, in anyopen(datasource, mode, reset)
#     405 openfunc = read_handlers[ext]
# --> 406 stream = _get_stream(datasource, openfunc, mode=mode)
#     407 if stream is not None:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:448, in _get_stream(filename, openfunction, mode)
#     447 if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 448     raise sys.exc_info()[1] from err
#     449 return None
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:442, in _get_stream(filename, openfunction, mode)
#     441 try:
# --> 442     stream = openfunction(filename, mode=mode)
#     443 except (IOError, OSError) as err:
#     444     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     445     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     446     # either the file isn't there or the permissions don't allow access.
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:522, in bz2_pickle_open(name, mode)
#     521 bz_mode = mode.replace("t", "")
# --> 522 binary_file = BZ2Picklable(name, bz_mode)
#     523 if "t" in mode:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:297, in BZ2Picklable.__init__(self, name, mode)
#     296 self._bz_mode = mode
# --> 297 super().__init__(name, mode)
#
# File ~/miniforge3/envs/md/lib/python3.12/bz2.py:81, in BZ2File.__init__(self, filename, mode, compresslevel)
#      80 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 81     self._fp = _builtin_open(filename, mode)
#      82     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ranjani/arg/Lys122Ala-Val123Arg_final.pdb'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[5], line 37
#      36 centered_traj_name = f"{pdb_name}_trajectory.dcd"
# ---> 37 mda_traj = utils.parallel_center_trajectory(f"{pdb_name}_final.pdb", f"{pdb_name}_trajectory.dcd", align=align, n_jobs=n_jobs, output_filename = centered_traj_name)
#      38 print(f"{round(time.time() - start_time,2)}s used for centering")
#
# File ~/md/utils/utils.py:132, in parallel_center_trajectory(pdb_filename, traj_filename, align, n_jobs, output_filename)
#     131 # Load Universe once to get number of frames.
# --> 132 u = mda.Universe(pdb_filename, traj_filename)
#     133 n_frames = u.trajectory.n_frames
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:417, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, fudge_factor, lower_bound, in_memory, context, to_guess, force_guess, in_memory_step, *coordinates, **kwargs)
#     416     self.filename = _check_file_like(topology)
# --> 417     topology = _topology_from_file_like(self.filename,
#     418                                         topology_format=topology_format,
#     419                                         **kwargs)
#     421 if topology is not None:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:121, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     118 if (err.errno is not None and
#     119     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120     # Runs if the error is propagated due to no permission / file not found
# --> 121     raise sys.exc_info()[1] from err
#     122 else:
#     123     # Runs when the parser fails
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:113, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     112     with parser(topology_file) as p:
# --> 113         topology = p.parse(**kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/topology/PDBParser.py:215, in PDBParser.parse(self, **kwargs)
#     209 """Parse atom information from PDB file
#     210
#     211 Returns
#     212 -------
#     213 MDAnalysis Topology object
#     214 """
# --> 215 top = self._parseatoms()
#     217 try:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/topology/PDBParser.py:252, in PDBParser._parseatoms(self)
#     251 last_wrapped_serial = 100000  # if serials wrap, start from here
# --> 252 with util.openany(self.filename) as f:
#     253     for line in f:
#
# File ~/miniforge3/envs/md/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:326, in openany(datasource, mode, reset)
#     284 """Context manager for :func:`anyopen`.
#     285
#     286 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     324 :func:`anyopen`
#     325 """
# --> 326 stream = anyopen(datasource, mode=mode, reset=reset)
#     327 try:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:406, in anyopen(datasource, mode, reset)
#     405 openfunc = read_handlers[ext]
# --> 406 stream = _get_stream(datasource, openfunc, mode=mode)
#     407 if stream is not None:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:448, in _get_stream(filename, openfunction, mode)
#     447 if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 448     raise sys.exc_info()[1] from err
#     449 return None
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:442, in _get_stream(filename, openfunction, mode)
#     441 try:
# --> 442     stream = openfunction(filename, mode=mode)
#     443 except (IOError, OSError) as err:
#     444     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     445     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     446     # either the file isn't there or the permissions don't allow access.
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:522, in bz2_pickle_open(name, mode)
#     521 bz_mode = mode.replace("t", "")
# --> 522 binary_file = BZ2Picklable(name, bz_mode)
#     523 if "t" in mode:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:297, in BZ2Picklable.__init__(self, name, mode)
#     296 self._bz_mode = mode
# --> 297 super().__init__(name, mode)
#
# File ~/miniforge3/envs/md/lib/python3.12/bz2.py:81, in BZ2File.__init__(self, filename, mode, compresslevel)
#      80 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 81     self._fp = _builtin_open(filename, mode)
#      82     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ranjani/arg/Lys122Ala-Val123Arg_final.pdb'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 37
#      35 #center proteins, This also resets the time of the first snapshot to 0 ps thus removing equillibration time
#      36 centered_traj_name = f"{pdb_name}_trajectory.dcd"
# ---> 37 mda_traj = utils.parallel_center_trajectory(f"{pdb_name}_final.pdb", f"{pdb_name}_trajectory.dcd", align=align, n_jobs=n_jobs, output_filename = centered_traj_name)
#      38 print(f"{round(time.time() - start_time,2)}s used for centering")
#      40 #dt is in ps
#
# File ~/md/utils/utils.py:132, in parallel_center_trajectory(pdb_filename, traj_filename, align, n_jobs, output_filename)
#     120 """
#     121 Splits the trajectory into blocks and processes each block in parallel.
#     122 After processing, the temporary files are concatenated into one final trajectory.
#    (...)
#     129     mda universe from the centered trajectory
#     130 """
#     131 # Load Universe once to get number of frames.
# --> 132 u = mda.Universe(pdb_filename, traj_filename)
#     133 n_frames = u.trajectory.n_frames
#     134 frames_per_block = n_frames // n_jobs
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:417, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, fudge_factor, lower_bound, in_memory, context, to_guess, force_guess, in_memory_step, *coordinates, **kwargs)
#     415 if not isinstance(topology, Topology) and not topology is None:
#     416     self.filename = _check_file_like(topology)
# --> 417     topology = _topology_from_file_like(self.filename,
#     418                                         topology_format=topology_format,
#     419                                         **kwargs)
#     421 if topology is not None:
#     422     self._topology = topology
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:121, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#     118     if (err.errno is not None and
#     119         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120         # Runs if the error is propagated due to no permission / file not found
# --> 121         raise sys.exc_info()[1] from err
#     122     else:
#     123         # Runs when the parser fails
#     124         raise IOError("Failed to load from the topology file {0}"
#     125                         " with parser {1}.\n"
#     126                         "Error: {2}".format(topology_file, parser, err))
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/core/universe.py:113, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     111 try:
#     112     with parser(topology_file) as p:
# --> 113         topology = p.parse(**kwargs)
#     114 except (IOError, OSError) as err:
#     115     # There are 2 kinds of errors that might be raised here:
#     116     # one because the file isn't present
#     117     # or the permissions are bad, second when the parser fails
#     118     if (err.errno is not None and
#     119         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     120         # Runs if the error is propagated due to no permission / file not found
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/topology/PDBParser.py:215, in PDBParser.parse(self, **kwargs)
#     208 def parse(self, **kwargs):
#     209     """Parse atom information from PDB file
#     210
#     211     Returns
#     212     -------
#     213     MDAnalysis Topology object
#     214     """
# --> 215     top = self._parseatoms()
#     217     try:
#     218         bonds = self._parsebonds(top.ids.values)
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/topology/PDBParser.py:252, in PDBParser._parseatoms(self)
#     250 self._wrapped_serials = False  # did serials go over 100k?
#     251 last_wrapped_serial = 100000  # if serials wrap, start from here
# --> 252 with util.openany(self.filename) as f:
#     253     for line in f:
#     254         line = line.strip()  # Remove extra spaces
#
# File ~/miniforge3/envs/md/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:326, in openany(datasource, mode, reset)
#     282 @contextmanager
#     283 def openany(datasource, mode='rt', reset=True):
#     284     """Context manager for :func:`anyopen`.
#     285
#     286     Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     324     :func:`anyopen`
#     325     """
# --> 326     stream = anyopen(datasource, mode=mode, reset=reset)
#     327     try:
#     328         yield stream
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:406, in anyopen(datasource, mode, reset)
#     404 for ext in ('bz2', 'gz', ''):  # file == '' should be last
#     405     openfunc = read_handlers[ext]
# --> 406     stream = _get_stream(datasource, openfunc, mode=mode)
#     407     if stream is not None:
#     408         break
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:448, in _get_stream(filename, openfunction, mode)
#     443 except (IOError, OSError) as err:
#     444     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     445     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     446     # either the file isn't there or the permissions don't allow access.
#     447     if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 448         raise sys.exc_info()[1] from err
#     449     return None
#     450 if mode.startswith('r'):
#     451     # additional check for reading (eg can we uncompress) --- is this needed?
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/util.py:442, in _get_stream(filename, openfunction, mode)
#     440 """Return open stream if *filename* can be opened with *openfunction* or else ``None``."""
#     441 try:
# --> 442     stream = openfunction(filename, mode=mode)
#     443 except (IOError, OSError) as err:
#     444     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     445     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     446     # either the file isn't there or the permissions don't allow access.
#     447     if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:522, in bz2_pickle_open(name, mode)
#     519     raise ValueError("Only read mode ('r', 'rt', 'rb') "
#     520                      "files can be pickled.")
#     521 bz_mode = mode.replace("t", "")
# --> 522 binary_file = BZ2Picklable(name, bz_mode)
#     523 if "t" in mode:
#     524     return TextIOPicklable(binary_file)
#
# File ~/miniforge3/envs/md/lib/python3.12/site-packages/MDAnalysis/lib/picklable_file_io.py:297, in BZ2Picklable.__init__(self, name, mode)
#     295 def __init__(self, name, mode='rb'):
#     296     self._bz_mode = mode
# --> 297     super().__init__(name, mode)
#
# File ~/miniforge3/envs/md/lib/python3.12/bz2.py:81, in BZ2File.__init__(self, filename, mode, compresslevel)
#      78     raise ValueError("Invalid mode: %r" % (mode,))
#      80 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 81     self._fp = _builtin_open(filename, mode)
#      82     self._closefp = True
#      83     self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ranjani/arg/Lys122Ala-Val123Arg_final.pdb'

# %%
#fake command line arguments
sys.argv = ["fake_name", "chiara/Z_complex.pdb", "--pdbfix","True","-l", "chiara/CD_lig.sdf", "-t", "0.2", "-dt", "4", "--resname", "UNK", "--dist", """resid 131 atom OG1, resname UNK atom N1x"""]

#Start the command line parser
parser = argparse.ArgumentParser(
                    prog='POS MD script',
                    description=(
                    "This script sets up a OPENMM  simulation of a protein (amber ff14)," 
                    "any small molecules/cofactors (Sage 2.2.1) as well as  water/ions using a 12-6 model (tip3pfb)."
                    "If using --pdbfix True then the structure will be prepared automatically. Otherwise prep is fully manual"),
                    epilog='Use with care and acknowledge Erik Sundén and the Per-Olof Syrén group at KTH Sweden')

parser.add_argument("pdb", type = str, help = "dockpreped PDB structure of the structure you want to simulate, including ligands") 
parser.add_argument("--pdbfix", type = str, default = "true", help = ("True or False depending on if your structure shall be PDBfixed." 
                                                                     "default = True \n good if you have a SEQRES and unresolved loops."
                                                                     "BEWARE, this function also removes all protein hydrogens and readds them" ))
parser.add_argument("-l", "--lig", type = str, default = None, help = ("optional parameter, SDF file containing all nonstandard ligands and cofactors." 
                                                                       "Convenientlly produced by drawing in chemdraw and exporting as SDF. Make sure SDF and PDB are in the same protonation state"
                                                                       "This is easilly done by checking ChimeraX dockpreps charge assignment when running dockprep.")) 
parser.add_argument("-t", "--timeprod", type = float, default= 0.2, help="Production simulation time in ns. Accepts floats and ints")
parser.add_argument("-dt", "--timestep", type = int, default= 4, help="Simulation timestep in fs. Accepts ints")
parser.add_argument("--resname", type = str, action="append", default= None, help="Residue names in PDB for which you want further analysis, eg ligand.\n"
                                                                            "several --resnames can be used at once", required=False)
parser.add_argument("--debug", type = bool, default= False, help="debug mode, prints more information while running", required=False)
parser.add_argument("--dist", type = str, action="append", default= None, help="""a pair of atom numbers eg "resid 131 atom OG1", "resname UNK atom N1x" for which you want 
a distance plot eg for monitoring near-attack conformations. specify using MDAnalysis/VMD natural language queries""", required=False)

# Parse arguments
args = parser.parse_args()

# Extract into variables
pdb_file = args.pdb
pdb_fixer = args.pdbfix
ligand_file = args.lig
simulation_time_ns = args.timeprod
timestep = args.timestep
pdb_name = os.path.splitext(pdb_file)[0]
analysis_resnames = args.resname
debug = args.debug
dist_residues = args.dist

print(dist_residues)
# Out:
# ['resid 131 atom OG1, resname UNK atom N1x']
