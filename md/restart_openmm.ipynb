# %%
from openmm.app import *
from openmm import *
from openmm.unit import *
import sys
from openff.toolkit import Molecule
from openmmforcefields.generators import SystemGenerator
import MDAnalysis as mda

path_to = "/home/erikna/compchem/md_data/unit-testing/5tbm/"
pdb = PDBFile(f"{path_to}5tbm_restart.pdb")

print(f"_final {PDBFile(f"{path_to}5tbm_final.pdb").topology.getNumAtoms()}")
print(f"_restart {PDBFile(f"{path_to}5tbm_restart.pdb").topology.getNumAtoms()}")

u = mda.Universe(f"{path_to}5tbm_trajectory.dcd")
print(f"mda {len(u.atoms)}")

if True:
    simulation = Simulation(pdb.topology, f"{path_to}5tbm_restart_system.xml", f"{path_to}5tbm_restart_integrator.xml")
    simulation.loadState(f"{path_to}5tbm_restart_state.xml")
    simulation.reporters.append(StateDataReporter(sys.stdout, 1000, step=True,
                    potentialEnergy=True, temperature=True, volume=True, remainingTime=True, totalSteps= 1000, speed=True))
    simulation.reporters.append(DCDReporter(f"{path_to}5tbm_trajectory.dcd", 1000, append = True))
    simulation.step(10000)
# Out:
# _final 24946
# _restart 24946
# mda 24946
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 24
#      21 simulation.reporters.append(StateDataReporter(sys.stdout, 1000, step=True,
#      22                 potentialEnergy=True, temperature=True, volume=True, remainingTime=True, totalSteps= 1000, speed=True))
#      23 simulation.reporters.append(DCDReporter(f"{path_to}5tbm_trajectory.dcd", 1000, append = True))
# ---> 24 simulation.step(10000)
#
# File ~/miniforge3/envs/whatcat/lib/python3.12/site-packages/openmm/app/simulation.py:147, in Simulation.step(self, steps)
#     145 def step(self, steps):
#     146     """Advance the simulation by integrating a specified number of time steps."""
# --> 147     self._simulate(endStep=self.currentStep+steps)
#
# File ~/miniforge3/envs/whatcat/lib/python3.12/site-packages/openmm/app/simulation.py:247, in Simulation._simulate(self, endStep, endTime)
#     244 # Generate the reports.
#     246 if len(wrapped) > 0:
# --> 247     self._generate_reports(wrapped, True)
#     248 if len(unwrapped) > 0:
#     249     self._generate_reports(unwrapped, False)
#
# File ~/miniforge3/envs/whatcat/lib/python3.12/site-packages/openmm/app/simulation.py:269, in Simulation._generate_reports(self, reports, periodic)
#     265 state = self.context.getState(getPositions=getPositions, getVelocities=getVelocities, getForces=getForces,
#     266                               getEnergy=getEnergy, getParameters=True, enforcePeriodicBox=periodic,
#     267                               groups=self.context.getIntegrator().getIntegrationForceGroups())
#     268 for reporter, next in reports:
# --> 269     reporter.report(self, state)
#
# File ~/miniforge3/envs/whatcat/lib/python3.12/site-packages/openmm/app/dcdreporter.py:103, in DCDReporter.report(self, simulation, state)
#      92 """Generate a report.
#      93
#      94 Parameters
#    (...)
#      99     The current state of the simulation
#     100 """
#     102 if self._dcd is None:
# --> 103     self._dcd = DCDFile(
#     104         self._out, simulation.topology, simulation.integrator.getStepSize(),
#     105         simulation.currentStep, self._reportInterval, self._append
#     106     )
#     107 self._dcd.writeModel(state.getPositions(), periodicBoxVectors=state.getPeriodicBoxVectors())
#
# File ~/miniforge3/envs/whatcat/lib/python3.12/site-packages/openmm/app/dcdfile.py:92, in DCDFile.__init__(self, file, topology, dt, firstStep, interval, append)
#      90     numAtoms = struct.unpack('<i', file.read(4))[0]
#      91     if numAtoms != len(list(topology.atoms())):
# ---> 92         raise ValueError('Cannot append to a DCD file that contains a different number of atoms')
#      93 else:
#      94     header = struct.pack('<i4c9if', 84, b'C', b'O', b'R', b'D', 0, firstStep, interval, 0, 0, 0, 0, 0, 0, dt)
#
# ValueError: Cannot append to a DCD file that contains a different number of atoms

# %%
#this specifies the size, start and end of the 2D RMSD matrix
#BEWARE N^2 scaling operation
tot_frames = 10
start_frame = 0
end_frame= 10
max_frames = 500

sparsity = (tot_frames - (tot_frames - end_frame) - start_frame)/ max_frames #500 is the biggest amount of frames judged to be plausible to compute
print(sparsity)

#Round up and convert to int by exploiting floating point remainder
sparsity = int(sparsity // 1 + (sparsity % 1 > 0))
print(sparsity)
print(sparsity // 1 + (sparsity % 1 > 0))
# Out:
# 0.02
# 1
# 1

# %%
# Out:
# Atom names in PDB: ['CH3', 'H1', 'H2', 'H3', 'C', 'O', 'N', 'H', 'CA', 'HA']
# Atom names in DCD: ['CH3', 'H1', 'H2', 'H3', 'C', 'O', 'N', 'H', 'CA', 'HA']
